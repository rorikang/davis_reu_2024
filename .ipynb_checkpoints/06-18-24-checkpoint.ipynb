# %%
import sys
import gizmo_analysis as gizmo
import utilities as ut
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
simulation_directory = '/Users/rorik/reu/m12i'

# %%
# Read star particles at z = 0, store as a python dictionary

part = gizmo.io.Read.read_snapshots(['star'], 'redshift', 0, simulation_directory, 
                                    assign_hosts_rotation=True, assign_formation_coordinates=True)
# Alternately, read all particle species at z = 0

# part = gizmo.io.Read.read_snapshots('all', 'redshift', 0, simulation_directory)
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  Users/rorik/reu/m12i/snapshot_times.txt
#
# * input redshift = 0:  using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Users/rorik/reu/m12i/output\snapdir_600\snapshot_600.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57060074 particles
#     star      (id = 4): 13976485 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     output\snapdir_600\snapshot_600.0.hdf5
#     output\snapdir_600\snapshot_600.1.hdf5
#     output\snapdir_600\snapshot_600.2.hdf5
#     output\snapdir_600\snapshot_600.3.hdf5
#
# * reading cosmological parameters from:  Users/rorik/reu/m12i\initial_condition\ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# ...

# %%
part['star'].keys()
# Out:
# dict_keys(['position', 'mass', 'massfraction', 'id.child', 'id.generation', 'id', 'potential', 'form.scalefactor', 'velocity', 'form.host.distance', 'form.host.velocity'])

# %% [markdown]
# ## Derived properties
#
# You can use __.prop('*property_name*')__ to derive other (more useful) quantities.
#
# Some properties that you may want include:
# -  'host.distance' : 3D distance of particles from the center of the galaxy in x,y,z grid [kpc physical]
# -  'host.distance.total' : Total (1D) distance from the center of the galaxy [kpc physical]
# -  'host.velocity' : 3D velocity of particles with respect to the center of the galaxy in x,y,z grid [km/s]
# -  'host.velocity.total' : Total (scalar) velocity [km/s]
#
# Star particles also have:
# -  'form.time' : Age of the Universe when the star particle formed [Gyr]
# -  'age' : Age of the star particle at the current snapshot [Gyr]
#
# Gas particles also have:
# -  'number.density' : [hydrogen atoms / cm^3]
#
# See the documentation in the gizmo_io.py file for all options of derived quantities.
#
# Here are a few examples of how to look at properties of star particles.

# %%
# stars formed within 30 kpc comoving of the galaxy
form_distances = part['star'].prop('host.form.distance.total')
form_scalefactors = part['star'].prop('form.scalefactor')
form_filter = (form_distances / form_scalefactors) < 30

# |z| < 3kpc
z_filter = abs(part['star'].prop('host.distance.principal.cyl')[::,2]) < 3

# r < 15 kpc
r_filter = part['star'].prop('host.distance.principal.cyl')[::,0] < 15
masks = z_filter & r_filter & form_filter

# %%
# position of stars in cylindrical coordinates
# First value is along the major axes (R, positive definite) [kpc physical]
# Second value is angle (phi, 0 to 2 * pi) [radian]
# Third value is vertical height wrt the disk (Z, signed) [kpc physical]

ps = part['star'].prop('host.distance.principal.cyl', masks) # in kpc

# Compute 3-D velocity in cylindrical coordinates
# First value is along the major axes
# Secod value is azimuthal velocity in the plane of the disk 
# (the disk is oriented) so the mean v_phi should be positive
# Third value is vertical velocity wrt the disk (signed)

vs = part['star'].prop('host.velocity.principal.cyl', masks) # in km/s

age = part['star'].prop('age', masks) # in gyr

# %%
# formation coordinates/velocity of stars in cylindrical coordinates
ps_form = part['star'].prop('form.host.distance.principal.cyl', masks)
vs_form = part['star'].prop('form.host.velocity.principal.cyl', masks)

# %%
R = ps[::, 0]
v_phi = vs[::, 1]
v_R = vs[::, 0]
v_z = vs[::, 2]

R_form = ps_form[::, 0]
v_phi_form = vs_form[::, 1]
v_R_form = vs_form[::, 0]
v_z_form = vs_form[::, 2]

# %%
from scipy.stats import binned_statistic

def bin_helper(x, y, bins, stat='mean'):

    stat, edges, _ = binned_statistic(x, y, statistic=stat, bins=14)
    std, edges, _ = binned_statistic(x, y, statistic='std', bins=14)
    bins = edges[:-1]
    
    return stat, std, bins

# %%
def plot_helper(x, y, label, stat='mean', ax=None):
    if ax==None:
        ax = plt.gca()
    ax.scatter(x, y, s=1, alpha=0.1)
    stat_y, std, bins = bin_helper(x, y, 14, stat=stat)
    
    ax.plot(bins, stat_y, 'ro-', label=label)
    ax.fill_between(bins, stat_y-std, stat_y+std, alpha=0.5, label='$\sigma=1$')
    ax.legend(loc='upper right')
    return ax

# %%
median_v_phi, std_v_phi, v_phi_bins = bin_helper(age, v_phi, 14, stat='median')

fig, axs = plt.subplots(1, 3, figsize=(18, 4), sharey=True, gridspec_kw={'width_ratios': [1, 1, 1]})
fig.suptitle('$v_{\phi}$ vs age')

H, xedges, yedges = np.histogram2d(age, v_phi, bins=100)
H = H.T
X, Y = np.meshgrid(xedges, yedges)
axs[0].pcolormesh(X, Y, H)
axs[0].set(xlabel = 'age [gyr]');

axs[1] = plot_helper(age, v_phi, 'median $v_{\phi}$', ax=axs[1], stat='median')
axs[1].set(xlabel = 'age [gyr]', ylabel = '$v_{\phi}$ [km/s]', title='today')

axs[2] = plot_helper(age, v_phi_form, 'formation median $v_{\phi}$', ax=axs[2], stat='median')
axs[2].set(title='formation', xlabel = 'Radius [kpc]');

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4), sharey=True)
fig.suptitle('Radial velocity vs age')

axs[0] = plot_helper(age, v_R, 'mean $v_R$', ax=axs[0])
axs[0].set(xlabel = 'age [gyr]', ylabel = 'Radial Velocity [km/s]', title='today')

axs[1] = plot_helper(age, v_R_form, 'mean $v_R$', ax=axs[1])
axs[1].set(xlabel = 'age [gyr]', title='formation');

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4), sharey=True)
fig.suptitle('$v_z$ vs age')

axs[0] = plot_helper(age, v_z, 'mean $v_z$', ax=axs[0])
axs[0].set(xlabel = 'age [gyr]', ylabel = '$v_z$ [km/s]', title='today')

axs[1] = plot_helper(age, v_z_form, 'mean $v_z$', ax=axs[1])
axs[1].set(xlabel = 'age [gyr]', title='formation');

# axs[1] = plot_helper(age, v_z, 'mean $v_z$', ax=axs[1])
# axs[1].set(xlabel = 'age [gyr]', ylabel = '$v_z$ [km/s]');

# %%
#specific momentum
L = (R*3.086e+16)*v_phi
L_form = (R_form*3.086e+16)*v_phi_form

#specific energy
KE = 1/2*(v_phi**2+v_R**2+v_z**2)
KE_form = 1/2*(v_phi_form**2+v_R_form**2+v_z_form**2)

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 8), sharex='col', sharey='row')
fig.suptitle('more trends vs age')

axs[0,0] = plot_helper(age, L, 'mean L', ax=axs[0,0])
axs[0,0].set(xlabel = 'age [gyr]', ylabel = 'specific L [km^2/s]', title='today')

axs[0,1] = plot_helper(age, L_form, 'mean L', ax=axs[0,1])
axs[0,1].set(xlabel = 'age [gyr]', title='formation')

axs[1,0] = plot_helper(age, KE, 'mean KE', ax=axs[1,0])
axs[1,0].set(xlabel = 'age [gyr]', ylabel = 'specific KE [km^2/s^2]');

axs[1,1] = plot_helper(age, KE_form, 'mean KE', ax=axs[1,1])
axs[1,1].set(xlabel = 'age [gyr]');
# Out:
# C:\Users\rorik\anaconda3\lib\site-packages\numpy\core\_methods.py:232: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\Users\rorik\anaconda3\lib\site-packages\numpy\core\_methods.py:243: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 8), sharex='col', sharey='row')
fig.suptitle('more trends vs radius')

axs[0,0] = plot_helper(R, L, 'mean L', ax=axs[0,0])
axs[0,0].set(ylabel = 'specific L [km^2/s]', title='today')

axs[0,1] = plot_helper(R, L_form, 'mean L', ax=axs[0,1])
axs[0,1].set(title='formation')

axs[1,0] = plot_helper(R, KE, 'mean KE', ax=axs[1,0])
axs[1,0].set(xlabel = 'Radius [kpc]', ylabel = 'specific KE [km^2/s^2]');

axs[1,1] = plot_helper(R, KE_form, 'mean KE', ax=axs[1,1])
axs[1,1].set(xlabel = 'Radius [kpc]');

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 4), sharex=True, gridspec_kw={'width_ratios': [1,1,1]})
fig.suptitle('trends vs radius')

axs[0] = plot_helper(R, v_phi, 'median $v_{\phi}$', ax=axs[0])
axs[0].set(xlabel = 'Radius [kpc]', ylabel = '$v_{\phi}$ [km/s]')

axs[1] = plot_helper(R, v_R, 'mean $v_R$', ax=axs[1])
axs[1].set(xlabel = 'Radius [kpc]', ylabel = 'Radial Velocity [km/s]')

axs[2] = plot_helper(R, v_z, 'mean $v_z$', ax=axs[2])
axs[2].set(xlabel = 'Radius [kpc]', ylabel = '$v_z$ [km/s]');

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 4))
fig.suptitle('more trends vs radius')

axs[0] = plot_helper(R, L, 'mean L', ax=axs[0])
axs[0].set(xlabel = 'Radius [kpc]', ylabel = 'specific L [km^2/s]')

axs[1] = plot_helper(R, KE, 'mean KE', ax=axs[1])
axs[1].set(xlabel = 'Radius [kpc]', ylabel = 'specific KE [km^2/s^2]');

# %% [markdown]
# ## Formation coordinates

# %%
R_form = ps_form[::, 0]
v_phi_form = vs_form[::, 1]
v_R_form = vs_form[::, 0]
v_z_form = vs_form[::, 2]

L_form = (R_form*3.086e+16)*v_phi_form
KE_form = 1/2*(v_phi_form**2+v_R_form**2+v_z_form**2)

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 4), sharex=True)
fig.suptitle('velocity trends vs radius')

axs[0] = plot_helper(R_form, v_phi_form, 'median $v_{\phi}$', ax=axs[0], stat='median')
axs[0].set(xlabel = 'Radius [kpc]', ylabel = '$v_{\phi}$ [km/s]', ylim=[-500, 600])

axs[1] = plot_helper(R_form, v_R_form, 'mean $v_R$', ax=axs[1])
axs[1].set(xlabel = 'Radius [kpc]', ylabel = 'Radial Velocity [km/s]', ylim=[-500, 1000])

axs[2] = plot_helper(R_form, v_z_form, 'mean $v_z$', ax=axs[2])
axs[2].set(xlabel = 'Radius [kpc]', ylabel = '$v_z$ [km/s]', ylim=[-700, 500]);

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 4), sharex=True)
fig.suptitle('more formation coordinate trends vs radius')

axs[0] = plot_helper(R_form, L_form, 'mean L', ax=axs[0])
axs[0].set(xlabel = 'Radius [kpc]', ylabel = 'specific L [km^2/s]')

axs[1] = plot_helper(R_form, KE_form, 'mean KE', ax=axs[1])
axs[1].set(xlabel = 'Radius [kpc]', ylabel = 'specific KE [km^2/s^2]', ylim=[-50000, 3e5]);

# %% [markdown]
# ## specific angular momentum
#
# $\ell = Rv_{\phi}$ for star particles at sun's current pos ($R=8 \pm 1$ kpc) today

# %%
form_distances = part[‘star’].prop(‘host.form.distance.total’)
form_scalefactors = part[‘star’].prop(‘form.scalefactor’)
masks = ((form_distances / form_scalefactors) < 30)
# then use masks to select the particles we want, as in:
part[‘star’].prop(‘age’, masks)

# %%
def filter_R8(i, a=ps): 
    return a[i][0]>7 and a[i][0]<9

R8_age = np.array([age[i] for i in range(len(age)) if filter_R8(i)])
R8_ps = np.array([ps[i] for i in range(len(ps)) if filter_R8(i)])
R8_vs = np.array([vs[i] for i in range(len(vs)) if filter_R8(i)])

R8_ps_form = np.array([ps_form[i] for i in range(len(ps_form)) if filter_R8(i)])
R8_vs_form = np.array([vs_form[i] for i in range(len(vs_form)) if filter_R8(i)])

# %%
ell = R8_ps[::, 0]*R8_vs[::, 1]
ell_form = R8_ps_form[::, 0]*R8_vs_form[::, 1]

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 4), sharex=True)
fig.suptitle('$\ell$ vs age')

axs[0] = plot_helper(R8_age, ell, 'mean $\ell$', ax=axs[0])
axs[0].set(xlabel = 'age [gyr]', ylabel = '$\ell$ [km^2/s]')
axs[0].grid()

axs[1] = plot_helper(R8_age, ell_form, 'mean $\ell$', ax=axs[1])
axs[1].set(xlabel = 'age [gyr]', ylabel = '$\ell$ at formation [km^2/s]',
          ylim=[-20000, 20000])
axs[1].grid();

# %% [markdown]
# $\ell$ seems to be smaller for older stars, both today and at formation (although much smaller trend at formation). 1 sigma scatter is much higher for older stars, especially at formation (because galaxy was less organized near the beginning probably?)

# %%
ell_diff = ell-ell_form

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 4))
fig.suptitle('distributions of change in $\ell$')

axs[0].hist(ell_diff, bins=100)
axs[0].set(xlabel='$\ell_{current}-\ell_{form}$ [km^2/s]', ylabel='num star particles', 
           xlim=[-1e4, 1e4])

axs[1] = plot_helper(R8_age, ell_diff, 'mean $\ell$', ax=axs[1])
axs[1].set(xlabel = 'age [gyr]', ylabel = 'change in $\ell$ [km^2/s]', ylim=[-3e4, 3e4]);

# %% [markdown]
# distribution of change in $\ell$ centered around zero, no trend with age (although 1 sigma of $\ell_{diff}$ is also higher for older stars)

# %%
vz_diff = R8_vs[::, 2]-R8_vs_form[::, 2]
vR_diff = R8_vs[::, 0]-R8_vs_form[::, 0]

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 4), sharex=True)
fig.suptitle('change in $\ell$ vs change in other velocity components')

axs[0] = plot_helper(vz_diff, ell_diff, 'mean $\ell_{diff}$', ax=axs[0])
axs[0].set(xlabel = 'change in $v_z$', ylabel = '$\ell_{diff}$', ylim=[-2e4, 2e4])
axs[0].grid()

axs[1] = plot_helper(vR_diff, ell_diff, 'mean $\ell_{diff}$', ax=axs[1])
axs[1].set(xlabel = 'change in $v_R$', ylabel = '$\ell_{diff}$', ylim=[-2e4, 2e4])
axs[1].grid();

# %% [markdown]
# no relationship between change in $\ell$ and change in vz or vr (maybe slight trend for very large changes in velocity components? doesn't seem very significant though.)
